# %% [markdown]
# <h1 style=">Universidad Castro Carazo</h1>
# <h2>Analisis Datos</h2>

# %% [markdown]
# <h1 style="color:#a9da88; text-align: center"> Universidad Castro Carazo</h1>
# <h2 style="color:#fb7968; text-align: center">Analisis datos</h2>
# <br/>
# <p style="font-family: sans-serif; text-align:justify">El analisis de datos es un proceso sistematico y metodico que implica la recopilacion e interpretacion y visualizacion de conjuntos de datos con el objetivo de extraer informacion significativa y relevante. Este proceso utiliza herramientas, tecnologias y  procesos para encontrar tendencias y resolver prolemas mediante datos.</p>

# %% [markdown]
# <table>
#     <tr>
#         <td>Repositorio del set de datos</td>
#         <td><a href="https://paletadecolores.com.mx/">Enlace</a></td>
#     </tr>
#     <tr>
#         <td>Paleta de colores</td>
#         <td><a href="https://paletadecolores.com.mx/">Enlace</a></td>
#     </tr>
# </table>

# %% [markdown]
# <h2>1. Carga y estandarizacion del set de datos</h2>
# <ul>
#     <li>Instalar las librerias necesarias</li>
#     <li>Importar los archivos csv</li>
#     <li>Revision general de los set de datos</li>
#     <li>Generar un unico Data set</li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
cols = [
    "symboling",
    "Normalized",
    "make",
    "fuel",
    "aspiration",
    "doors"
    "style",
    "wheels",
    "engine"
    "base",
    "length",
    "width",
    "heingt",
    "curb",
    "engineType",
    "Cylind3rs",
    "engine size",
    "system",
    "bor3",
    "stroke",
    "compression",
    "hOrsepower",
    "peak",
    "CITY",
    "Higway",
    "price"
]

# %%
# dfAutos1 = pd.read_csv("Autos1.csv", names=cols)
# dfAutos2 = pd.read_csv("autos.csv", names=cols)
dfAutos1 = pd.read_csv("DataSet_Autos01.csv", names=cols)
dfAutos2 = pd.read_csv("DataSet_Autos02.csv", names=cols)
print(f"La dimension del set de datos 1 es: {dfAutos1.shape}")
print(f"La dimension del set de datos 2 es: {dfAutos2.shape}")
# Out:
# La dimension del set de datos 1 es: (201, 24)
# La dimension del set de datos 2 es: (201, 24)

# %%
dfAutos1.head(3)
# Out:
#                symboling Normalized   make  fuel   aspiration doorsstyle  \
# NaN   3 ?    alfa-romero        gas    std   two  convertible        rwd
# 26.0  1 148        dodge        gas  turbo     ?        sedan        fwd
# 185.0 2 94    volkswagen        gas    std  four        sedan        fwd
#
#             wheels  enginebase  length  width  ...  engine size  system  bor3  \
# NaN   3 ?    front        88.6   168.8   64.1  ...          130    mpfi  3.47
# 26.0  1 148  front        93.7   157.3   63.8  ...           98    mpfi  3.03
# 185.0 2 94   front        97.3   171.7   65.5  ...          109    mpfi  3.19
#
#             stroke  compression hOrsepower  peak CITY  Higway  price
# NaN   3 ?     2.68          9.0        111  5000   21      27  13495
# 26.0  1 148   3.39          7.6        102  5500   24      30   8558
# 185.0 2 94    3.40          9.0         85  5250   27      34   8495
#
# [3 rows x 24 columns]

# %%
dfAutos2.tail(3)
# Out:
#             symboling Normalized make  fuel aspiration doorsstyle wheels  \
# 164.0 1 168    toyota        gas  std   two      sedan        rwd  front
# 3.0   2 164      audi        gas  std  four      sedan        4wd  front
# 112.0 0 ?      peugot        gas  std  four      wagon        rwd  front
#
#              enginebase  length  width  ...  engine size  system  bor3 stroke  \
# 164.0 1 168        94.5   168.7   64.0  ...           98    mpfi  3.24   3.08
# 3.0   2 164        99.4   176.6   66.4  ...          136    mpfi  3.19   3.40
# 112.0 0 ?         114.2   198.9   68.4  ...          120    mpfi  3.46   2.19
#
#              compression hOrsepower  peak CITY  Higway  price
# 164.0 1 168          9.4        112  6600   26      29   9298
# 3.0   2 164          8.0        115  5500   18      22  17450
# 112.0 0 ?            8.4         95  5000   19      24  16695
#
# [3 rows x 24 columns]

# %% [markdown]
# <h4>1.3) Revisar los encabezados de los set de datos</h4>
# <h5>
#     Sanas practicas para nombrar las variables:
#     <ol>
#         <li>Los nombres de variables no deben de empezar con un numero</li>
#         <li>Los nombres no pueden ser iguales a una palabra reservada (for, if, print)</li>
#         <li>
#             Los nombres no deben de contener espacios (engine size -> engineSize / engine-size)
#         </li>
#         <li>
#             Los nombres de variables deben estar en el mismo idioma
#         </li>
#         <li>
#             Los nombres de variables deben estar todos en Minuscula o Mayuscula
#         </li>
#     </ol>
# </h5>

# %%
print(f"Listado de variables dfAutos1: {dfAutos1.columns}")
print(f"Listado de variables dfAutos2: {dfAutos2.columns}")
# Out:
# Listado de variables dfAutos1: Index(['symboling', 'Normalized', 'make', 'fuel', 'aspiration', 'doorsstyle',
#        'wheels', 'enginebase', 'length', 'width', 'heingt', 'curb',
#        'engineType', 'Cylind3rs', 'engine size', 'system', 'bor3', 'stroke',
#        'compression', 'hOrsepower', 'peak', 'CITY', 'Higway', 'price'],
#       dtype='object')
# Listado de variables dfAutos2: Index(['symboling', 'Normalized', 'make', 'fuel', 'aspiration', 'doorsstyle',
#        'wheels', 'enginebase', 'length', 'width', 'heingt', 'curb',
#        'engineType', 'Cylind3rs', 'engine size', 'system', 'bor3', 'stroke',
#        'compression', 'hOrsepower', 'peak', 'CITY', 'Higway', 'price'],
#       dtype='object')

# %% [markdown]
# <h4>1.4) Generar un unico set de datos</h4>
# <h5>
#     Puntos a considerar:
#     <ol>
#         <li>Las variables se llamen igual</li>
#         <li>Contener la misma cantidad de variables y estar en el mismo orden</li>
#     </ol>
# </h5>

# %%
unionArchivos = (dfAutos1, dfAutos2)
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (402, 24)

# %%
dfAutos.head(5)
# Out:
#                symboling Normalized   make  fuel   aspiration doorsstyle  \
# NaN   3 ?    alfa-romero        gas    std   two  convertible        rwd
# 26.0  1 148        dodge        gas  turbo     ?        sedan        fwd
# 185.0 2 94    volkswagen        gas    std  four        sedan        fwd
# 112.0 0 ?         peugot        gas    std  four        wagon        rwd
# 78.0  1 161   mitsubishi        gas  turbo   two    hatchback        fwd
#
#             wheels  enginebase  length  width  ...  engine size  system  bor3  \
# NaN   3 ?    front        88.6   168.8   64.1  ...          130    mpfi  3.47
# 26.0  1 148  front        93.7   157.3   63.8  ...           98    mpfi  3.03
# 185.0 2 94   front        97.3   171.7   65.5  ...          109    mpfi  3.19
# 112.0 0 ?    front       114.2   198.9   68.4  ...          120    mpfi  3.46
# 78.0  1 161  front        93.0   157.3   63.8  ...           98    spdi  3.03
#
#             stroke  compression hOrsepower  peak CITY  Higway  price
# NaN   3 ?     2.68          9.0        111  5000   21      27  13495
# 26.0  1 148   3.39          7.6        102  5500   24      30   8558
# 185.0 2 94    3.40          9.0         85  5250   27      34   8495
# 112.0 0 ?     2.19          8.4         95  5000   19      24  16695
# 78.0  1 161   3.39          7.6        102  5500   24      30   7689
#
# [5 rows x 24 columns]

# %%
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos.head(5)
# Out:
#      symboling Normalized   make  fuel   aspiration doorsstyle wheels  \
# 0  alfa-romero        gas    std   two  convertible        rwd  front
# 1        dodge        gas  turbo     ?        sedan        fwd  front
# 2   volkswagen        gas    std  four        sedan        fwd  front
# 3       peugot        gas    std  four        wagon        rwd  front
# 4   mitsubishi        gas  turbo   two    hatchback        fwd  front
#
#    enginebase  length  width  ...  engine size  system  bor3 stroke  \
# 0        88.6   168.8   64.1  ...          130    mpfi  3.47   2.68
# 1        93.7   157.3   63.8  ...           98    mpfi  3.03   3.39
# 2        97.3   171.7   65.5  ...          109    mpfi  3.19   3.40
# 3       114.2   198.9   68.4  ...          120    mpfi  3.46   2.19
# 4        93.0   157.3   63.8  ...           98    spdi  3.03   3.39
#
#    compression hOrsepower  peak CITY  Higway  price
# 0          9.0        111  5000   21      27  13495
# 1          7.6        102  5500   24      30   8558
# 2          9.0         85  5250   27      34   8495
# 3          8.4         95  5000   19      24  16695
# 4          7.6        102  5500   24      30   7689
#
# [5 rows x 24 columns]

# %%
dfAutos.tail(5)
# Out:
#     symboling Normalized make  fuel aspiration doorsstyle wheels  enginebase  \
# 397     honda        gas  std   two  hatchback        fwd  front        96.5
# 398     mazda        gas  std  four      sedan        fwd  front        98.8
# 399    toyota        gas  std   two      sedan        rwd  front        94.5
# 400      audi        gas  std  four      sedan        4wd  front        99.4
# 401    peugot        gas  std  four      wagon        rwd  front       114.2
#
#      length  width  ...  engine size  system  bor3 stroke  compression  \
# 397   167.5   65.2  ...          110    1bbl  3.15   3.58          9.0
# 398   177.8   66.5  ...          122    2bbl  3.39   3.39          8.6
# 399   168.7   64.0  ...           98    mpfi  3.24   3.08          9.4
# 400   176.6   66.4  ...          136    mpfi  3.19   3.40          8.0
# 401   198.9   68.4  ...          120    mpfi  3.46   2.19          8.4
#
#     hOrsepower  peak CITY  Higway  price
# 397         86  5800   27      33   7895
# 398         84  4800   26      32   8495
# 399        112  6600   26      29   9298
# 400        115  5500   18      22  17450
# 401         95  5000   19      24  16695
#
# [5 rows x 24 columns]

# %%
dfAutos.columns
# Out:
# Index(['symboling', 'Normalized', 'make', 'fuel', 'aspiration', 'doorsstyle',
#        'wheels', 'enginebase', 'length', 'width', 'heingt', 'curb',
#        'engineType', 'Cylind3rs', 'engine size', 'system', 'bor3', 'stroke',
#        'compression', 'hOrsepower', 'peak', 'CITY', 'Higway', 'price'],
#       dtype='object')

# %%
dfAutos.rename({'Normalized':'normalized'
                ,'Cylind3rs':'cylinders'
                ,'engine size':'engineSize'
                ,'bor3':'bore'
                ,'hOrsepower':'horsepower'
                ,'CITY':'city'
                ,'Higway':'higway'
               }, axis=1, inplace=True)
#axis 1 es horizontal y axis 0 es vertical

dfAutos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doorsstyle',
#        'wheels', 'enginebase', 'length', 'width', 'heingt', 'curb',
#        'engineType', 'cylinders', 'engineSize', 'system', 'bore', 'stroke',
#        'compression', 'horsepower', 'peak', 'city', 'higway', 'price'],
#       dtype='object')

# %%
dfAutos.head(3)
# Out:
#      symboling normalized   make  fuel   aspiration doorsstyle wheels  \
# 0  alfa-romero        gas    std   two  convertible        rwd  front
# 1        dodge        gas  turbo     ?        sedan        fwd  front
# 2   volkswagen        gas    std  four        sedan        fwd  front
#
#    enginebase  length  width  ...  engineSize  system  bore stroke  \
# 0        88.6   168.8   64.1  ...         130    mpfi  3.47   2.68
# 1        93.7   157.3   63.8  ...          98    mpfi  3.03   3.39
# 2        97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
#
#    compression horsepower  peak city  higway  price
# 0          9.0        111  5000   21      27  13495
# 1          7.6        102  5500   24      30   8558
# 2          9.0         85  5250   27      34   8495
#
# [3 rows x 24 columns]

# %% [markdown]
# <h2>2. Manejo de valores faltantes</h2>
# <ol>
#     <li>Identificar como se muestran los valores faltantes(NaN, ?, null, EspacioEnBlanco)</li>
#     <li>Contar la cantidad de valores faltantes en cada uan de las caracteristicas</li>
#     <li>Imputacion simple de valores numericos</li>
#     <li>Imputacion simple de valores categoricos</li>
#     <li>Eliminar observaciones o registros</li>
# </ol>
#
# <h4>2.1 Identificar como se muestran los valores faltantes</h4>

# %%
dfAutos.head(15)
# Out:
#       symboling normalized   make  fuel   aspiration doorsstyle wheels  \
# 0   alfa-romero        gas    std   two  convertible        rwd  front
# 1         dodge        gas  turbo     ?        sedan        fwd  front
# 2    volkswagen        gas    std  four        sedan        fwd  front
# 3        peugot        gas    std  four        wagon        rwd  front
# 4    mitsubishi        gas  turbo   two    hatchback        fwd  front
# 5         dodge        gas    std   two    hatchback        fwd  front
# 6       porsche        gas    std   two      hardtop        rwd   rear
# 7        toyota        gas    std   two        sedan        rwd  front
# 8          saab        gas    std  four        sedan        fwd  front
# 9         dodge        gas    std  four    hatchback        fwd  front
# 10        volvo        gas    std  four        wagon        rwd  front
# 11       toyota        gas    std   two      hardtop        rwd  front
# 12         audi        gas    std  four        sedan        4wd  front
# 13   volkswagen        gas    std  four        sedan        fwd  front
# 14       peugot        gas    std  four        sedan        rwd  front
#
#     enginebase  length  width  ...  engineSize  system  bore stroke  \
# 0         88.6   168.8   64.1  ...         130    mpfi  3.47   2.68
# 1         93.7   157.3   63.8  ...          98    mpfi  3.03   3.39
# 2         97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 3        114.2   198.9   68.4  ...         120    mpfi  3.46   2.19
# 4         93.0   157.3   63.8  ...          98    spdi  3.03   3.39
# 5         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 6         89.5   168.9   65.0  ...         194    mpfi  3.74   2.90
# 7         94.5   168.7   64.0  ...          98    mpfi  3.24   3.08
# 8         99.1   186.6   66.5  ...         121    mpfi  3.54   3.07
# 9         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 10       104.3   188.8   67.2  ...         141    mpfi  3.78   3.15
# 11        98.4   176.2   65.6  ...         146    mpfi  3.62   3.50
# 12        99.4   176.6   66.4  ...         136    mpfi  3.19   3.40
# 13        97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 14       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
#
#     compression horsepower  peak city  higway  price
# 0          9.00        111  5000   21      27  13495
# 1          7.60        102  5500   24      30   8558
# 2          9.00         85  5250   27      34   8495
# 3          8.40         95  5000   19      24  16695
# 4          7.60        102  5500   24      30   7689
# 5          9.41         68  5500   37      41   5572
# 6          9.50        207  5900   17      25  32528
# 7          9.40        112  6600   26      29   9298
# 8          9.30        110  5250   21      28  12170
# 9          9.40         68  5500   31      38   6229
# 10         9.50        114  5400   23      28  13415
# 11         9.30        116  4800   24      30  11199
# 12         8.00        115  5500   18      22  17450
# 13         9.00         85  5250   27      34   8195
# 14         8.40         97  5000   19      24  16630
#
# [15 rows x 24 columns]

# %%
dfAutos["normalized"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
dfAutos["stroke"].unique()
# Out:
# array(['2.68', '3.39', '3.40', '2.19', '3.23', '2.90', '3.08', '3.07',
#        '3.15', '3.50', '3.19', '3.86', '3.35', '3.58', '3.64', '?',
#        '3.41', '3.27', '3.54', '3.46', '3.29', '3.11', '2.64', '3.03',
#        '3.52', '3.90', '4.17', '3.16', '2.07', '3.47', '2.76', '3.12',
#        '3.10', '2.80'], dtype=object)

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    402 non-null    object
#  1   normalized   402 non-null    object
#  2   make         402 non-null    object
#  3   fuel         402 non-null    object
#  4   aspiration   402 non-null    object
#  5   doorsstyle   402 non-null    object
#  6   wheels       402 non-null    object
#  7   enginebase   402 non-null    float64
#  8   length       402 non-null    float64
#  9   width        402 non-null    float64
#  10  heingt       402 non-null    float64
#  11  curb         402 non-null    int64
#  12  engineType   402 non-null    object
#  13  cylinders    402 non-null    object
#  14  engineSize   402 non-null    int64
#  15  system       402 non-null    object
#  16  bore         402 non-null    object
#  17  stroke       402 non-null    object
#  18  compression  402 non-null    float64
#  19  horsepower   402 non-null    object
#  20  peak         402 non-null    object
#  21  city         402 non-null    int64
#  22  higway       402 non-null    int64
#  23  price        402 non-null    object
# dtypes: float64(5), int64(4), object(15)
# memory usage: 75.5+ KB

# %% [markdown]
# <h4>2.2 Contar los valores faltantes</h4>

# %%
dfAutos.replace('?', np.nan, inplace=True)

# %%
dfTemp = dfAutos.isnull()
dfTemp.head(10)
# Out:
#    symboling  normalized   make   fuel  aspiration  doorsstyle  wheels  \
# 0      False       False  False  False       False       False   False
# 1      False       False  False   True       False       False   False
# 2      False       False  False  False       False       False   False
# 3      False       False  False  False       False       False   False
# 4      False       False  False  False       False       False   False
# 5      False       False  False  False       False       False   False
# 6      False       False  False  False       False       False   False
# 7      False       False  False  False       False       False   False
# 8      False       False  False  False       False       False   False
# 9      False       False  False  False       False       False   False
#
#    enginebase  length  width  ...  engineSize  system   bore  stroke  \
# 0       False   False  False  ...       False   False  False   False
# 1       False   False  False  ...       False   False  False   False
# 2       False   False  False  ...       False   False  False   False
# 3       False   False  False  ...       False   False  False   False
# 4       False   False  False  ...       False   False  False   False
# 5       False   False  False  ...       False   False  False   False
# 6       False   False  False  ...       False   False  False   False
# 7       False   False  False  ...       False   False  False   False
# 8       False   False  False  ...       False   False  False   False
# 9       False   False  False  ...       False   False  False   False
#
#    compression  horsepower   peak   city  higway  price
# 0        False       False  False  False   False  False
# 1        False       False  False  False   False  False
# 2        False       False  False  False   False  False
# 3        False       False  False  False   False  False
# 4        False       False  False  False   False  False
# 5        False       False  False  False   False  False
# 6        False       False  False  False   False  False
# 7        False       False  False  False   False  False
# 8        False       False  False  False   False  False
# 9        False       False  False  False   False  False
#
# [10 rows x 24 columns]

# %%
dfAutos["fuel"].unique()
# Out:
# array(['two', nan, 'four'], dtype=object)

# %%
for variable in dfTemp.columns.values.tolist():
    print(dfTemp[variable].value_counts())
    print('')
# Out:
# symboling
# False    402
# Name: count, dtype: int64
#
# normalized
# False    402
# Name: count, dtype: int64
#
# make
# False    402
# Name: count, dtype: int64
#
# fuel
# False    399
# True       3
# Name: count, dtype: int64
#
# aspiration
# False    402
# Name: count, dtype: int64
#
# doorsstyle
# False    402
# Name: count, dtype: int64
#
# wheels
# False    402
# Name: count, dtype: int64
#
# enginebase
# False    402
# Name: count, dtype: int64
#
# length
# False    402
# Name: count, dtype: int64
#
# width
# False    402
# Name: count, dtype: int64
#
# heingt
# False    402
# Name: count, dtype: int64
#
# curb
# False    402
# Name: count, dtype: int64
#
# engineType
# False    402
# Name: count, dtype: int64
#
# cylinders
# False    402
# Name: count, dtype: int64
#
# engineSize
# False    402
# Name: count, dtype: int64
#
# system
# False    402
# Name: count, dtype: int64
#
# bore
# False    396
# True       6
# Name: count, dtype: int64
#
# stroke
# False    396
# True       6
# Name: count, dtype: int64
#
# compression
# False    402
# Name: count, dtype: int64
#
# horsepower
# False    398
# True       4
# Name: count, dtype: int64
#
# peak
# False    398
# True       4
# Name: count, dtype: int64
#
# city
# False    402
# Name: count, dtype: int64
#
# higway
# False    402
# Name: count, dtype: int64
#
# price
# False    394
# True       8
# Name: count, dtype: int64

# %% [markdown]
# <h4>Axis 1 => columns</h4>
# <h4>Axis 0 => rows</h4>

# %%
#Crear otro dataframe para probar 
dfAutosTest = pd.read_csv("DataSet_Autos01.csv", names=cols)

# %%
dfAutosTest.reset_index(drop=True, inplace=True)

# %%
dfAutosTest.rename({'Normalized':'normalized'
                ,'Cylind3rs':'cylinders'
                ,'engine size':'engineSize'
                ,'bor3':'bore'
                ,'hOrsepower':'horsepower'
                ,'CITY':'city'
                ,'Higway':'higway'
               }, axis=1, inplace=True)

# %%
#Reemplazar ? por na de numpy
dfAutosTest.replace('?', np.nan, inplace=True)

# %%
dfAutosTest.head(20) #fuel tiene un NaN
# Out:
#       symboling normalized   make  fuel   aspiration doorsstyle wheels  \
# 0   alfa-romero        gas    std   two  convertible        rwd  front
# 1         dodge        gas  turbo   NaN        sedan        fwd  front
# 2    volkswagen        gas    std  four        sedan        fwd  front
# 3        peugot        gas    std  four        wagon        rwd  front
# 4    mitsubishi        gas  turbo   two    hatchback        fwd  front
# 5         dodge        gas    std   two    hatchback        fwd  front
# 6       porsche        gas    std   two      hardtop        rwd   rear
# 7        toyota        gas    std   two        sedan        rwd  front
# 8          saab        gas    std  four        sedan        fwd  front
# 9         dodge        gas    std  four    hatchback        fwd  front
# 10        volvo        gas    std  four        wagon        rwd  front
# 11       toyota        gas    std   two      hardtop        rwd  front
# 12         audi        gas    std  four        sedan        4wd  front
# 13   volkswagen        gas    std  four        sedan        fwd  front
# 14       peugot        gas    std  four        sedan        rwd  front
# 15   mitsubishi        gas  turbo   two    hatchback        fwd  front
# 16       toyota        gas    std  four        sedan        rwd  front
# 17        mazda        gas    std  four        sedan        fwd  front
# 18       peugot        gas    std  four        sedan        rwd  front
# 19         audi        gas  turbo  four        sedan        fwd  front
#
#     enginebase  length  width  ...  engineSize  system  bore stroke  \
# 0         88.6   168.8   64.1  ...         130    mpfi  3.47   2.68
# 1         93.7   157.3   63.8  ...          98    mpfi  3.03   3.39
# 2         97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 3        114.2   198.9   68.4  ...         120    mpfi  3.46   2.19
# 4         93.0   157.3   63.8  ...          98    spdi  3.03   3.39
# 5         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 6         89.5   168.9   65.0  ...         194    mpfi  3.74   2.90
# 7         94.5   168.7   64.0  ...          98    mpfi  3.24   3.08
# 8         99.1   186.6   66.5  ...         121    mpfi  3.54   3.07
# 9         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 10       104.3   188.8   67.2  ...         141    mpfi  3.78   3.15
# 11        98.4   176.2   65.6  ...         146    mpfi  3.62   3.50
# 12        99.4   176.6   66.4  ...         136    mpfi  3.19   3.40
# 13        97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 14       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 15        95.9   173.2   66.3  ...         156    spdi  3.59   3.86
# 16       104.5   187.8   66.5  ...         171    mpfi  3.27   3.35
# 17        98.8   177.8   66.5  ...         122    2bbl  3.39   3.39
# 18       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 19       105.8   192.7   71.4  ...         131    mpfi  3.13   3.40
#
#     compression horsepower  peak city  higway  price
# 0          9.00        111  5000   21      27  13495
# 1          7.60        102  5500   24      30   8558
# 2          9.00         85  5250   27      34   8495
# 3          8.40         95  5000   19      24  16695
# 4          7.60        102  5500   24      30   7689
# 5          9.41         68  5500   37      41   5572
# 6          9.50        207  5900   17      25  32528
# 7          9.40        112  6600   26      29   9298
# 8          9.30        110  5250   21      28  12170
# 9          9.40         68  5500   31      38   6229
# 10         9.50        114  5400   23      28  13415
# 11         9.30        116  4800   24      30  11199
# 12         8.00        115  5500   18      22  17450
# 13         9.00         85  5250   27      34   8195
# 14         8.40         97  5000   19      24  16630
# 15         7.00        145  5000   19      24  14489
# 16         9.20        156  5200   20      24  15690
# 17         8.60         84  4800   26      32   8495
# 18         8.40         97  5000   19      24  11900
# 19         8.30        140  5500   17      20  23875
#
# [20 rows x 24 columns]

# %%
#Cambiar el nan de fuel por 0
df_fillna_zero = dfAutosTest.fillna(0)
df_fillna_zero.head(20)
# Out:
#       symboling normalized   make  fuel   aspiration doorsstyle wheels  \
# 0   alfa-romero        gas    std   two  convertible        rwd  front
# 1         dodge        gas  turbo     0        sedan        fwd  front
# 2    volkswagen        gas    std  four        sedan        fwd  front
# 3        peugot        gas    std  four        wagon        rwd  front
# 4    mitsubishi        gas  turbo   two    hatchback        fwd  front
# 5         dodge        gas    std   two    hatchback        fwd  front
# 6       porsche        gas    std   two      hardtop        rwd   rear
# 7        toyota        gas    std   two        sedan        rwd  front
# 8          saab        gas    std  four        sedan        fwd  front
# 9         dodge        gas    std  four    hatchback        fwd  front
# 10        volvo        gas    std  four        wagon        rwd  front
# 11       toyota        gas    std   two      hardtop        rwd  front
# 12         audi        gas    std  four        sedan        4wd  front
# 13   volkswagen        gas    std  four        sedan        fwd  front
# 14       peugot        gas    std  four        sedan        rwd  front
# 15   mitsubishi        gas  turbo   two    hatchback        fwd  front
# 16       toyota        gas    std  four        sedan        rwd  front
# 17        mazda        gas    std  four        sedan        fwd  front
# 18       peugot        gas    std  four        sedan        rwd  front
# 19         audi        gas  turbo  four        sedan        fwd  front
#
#     enginebase  length  width  ...  engineSize  system  bore stroke  \
# 0         88.6   168.8   64.1  ...         130    mpfi  3.47   2.68
# 1         93.7   157.3   63.8  ...          98    mpfi  3.03   3.39
# 2         97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 3        114.2   198.9   68.4  ...         120    mpfi  3.46   2.19
# 4         93.0   157.3   63.8  ...          98    spdi  3.03   3.39
# 5         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 6         89.5   168.9   65.0  ...         194    mpfi  3.74   2.90
# 7         94.5   168.7   64.0  ...          98    mpfi  3.24   3.08
# 8         99.1   186.6   66.5  ...         121    mpfi  3.54   3.07
# 9         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 10       104.3   188.8   67.2  ...         141    mpfi  3.78   3.15
# 11        98.4   176.2   65.6  ...         146    mpfi  3.62   3.50
# 12        99.4   176.6   66.4  ...         136    mpfi  3.19   3.40
# 13        97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 14       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 15        95.9   173.2   66.3  ...         156    spdi  3.59   3.86
# 16       104.5   187.8   66.5  ...         171    mpfi  3.27   3.35
# 17        98.8   177.8   66.5  ...         122    2bbl  3.39   3.39
# 18       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 19       105.8   192.7   71.4  ...         131    mpfi  3.13   3.40
#
#     compression horsepower  peak city  higway  price
# 0          9.00        111  5000   21      27  13495
# 1          7.60        102  5500   24      30   8558
# 2          9.00         85  5250   27      34   8495
# 3          8.40         95  5000   19      24  16695
# 4          7.60        102  5500   24      30   7689
# 5          9.41         68  5500   37      41   5572
# 6          9.50        207  5900   17      25  32528
# 7          9.40        112  6600   26      29   9298
# 8          9.30        110  5250   21      28  12170
# 9          9.40         68  5500   31      38   6229
# 10         9.50        114  5400   23      28  13415
# 11         9.30        116  4800   24      30  11199
# 12         8.00        115  5500   18      22  17450
# 13         9.00         85  5250   27      34   8195
# 14         8.40         97  5000   19      24  16630
# 15         7.00        145  5000   19      24  14489
# 16         9.20        156  5200   20      24  15690
# 17         8.60         84  4800   26      32   8495
# 18         8.40         97  5000   19      24  11900
# 19         8.30        140  5500   17      20  23875
#
# [20 rows x 24 columns]

# %%
df_fillna_mode = dfAutosTest.fillna(dfAutosTest["fuel"].mode()[0])
df_fillna_mode.head(20)
# Out:
#       symboling normalized   make  fuel   aspiration doorsstyle wheels  \
# 0   alfa-romero        gas    std   two  convertible        rwd  front
# 1         dodge        gas  turbo  four        sedan        fwd  front
# 2    volkswagen        gas    std  four        sedan        fwd  front
# 3        peugot        gas    std  four        wagon        rwd  front
# 4    mitsubishi        gas  turbo   two    hatchback        fwd  front
# 5         dodge        gas    std   two    hatchback        fwd  front
# 6       porsche        gas    std   two      hardtop        rwd   rear
# 7        toyota        gas    std   two        sedan        rwd  front
# 8          saab        gas    std  four        sedan        fwd  front
# 9         dodge        gas    std  four    hatchback        fwd  front
# 10        volvo        gas    std  four        wagon        rwd  front
# 11       toyota        gas    std   two      hardtop        rwd  front
# 12         audi        gas    std  four        sedan        4wd  front
# 13   volkswagen        gas    std  four        sedan        fwd  front
# 14       peugot        gas    std  four        sedan        rwd  front
# 15   mitsubishi        gas  turbo   two    hatchback        fwd  front
# 16       toyota        gas    std  four        sedan        rwd  front
# 17        mazda        gas    std  four        sedan        fwd  front
# 18       peugot        gas    std  four        sedan        rwd  front
# 19         audi        gas  turbo  four        sedan        fwd  front
#
#     enginebase  length  width  ...  engineSize  system  bore stroke  \
# 0         88.6   168.8   64.1  ...         130    mpfi  3.47   2.68
# 1         93.7   157.3   63.8  ...          98    mpfi  3.03   3.39
# 2         97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 3        114.2   198.9   68.4  ...         120    mpfi  3.46   2.19
# 4         93.0   157.3   63.8  ...          98    spdi  3.03   3.39
# 5         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 6         89.5   168.9   65.0  ...         194    mpfi  3.74   2.90
# 7         94.5   168.7   64.0  ...          98    mpfi  3.24   3.08
# 8         99.1   186.6   66.5  ...         121    mpfi  3.54   3.07
# 9         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 10       104.3   188.8   67.2  ...         141    mpfi  3.78   3.15
# 11        98.4   176.2   65.6  ...         146    mpfi  3.62   3.50
# 12        99.4   176.6   66.4  ...         136    mpfi  3.19   3.40
# 13        97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 14       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 15        95.9   173.2   66.3  ...         156    spdi  3.59   3.86
# 16       104.5   187.8   66.5  ...         171    mpfi  3.27   3.35
# 17        98.8   177.8   66.5  ...         122    2bbl  3.39   3.39
# 18       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 19       105.8   192.7   71.4  ...         131    mpfi  3.13   3.40
#
#     compression horsepower  peak city  higway  price
# 0          9.00        111  5000   21      27  13495
# 1          7.60        102  5500   24      30   8558
# 2          9.00         85  5250   27      34   8495
# 3          8.40         95  5000   19      24  16695
# 4          7.60        102  5500   24      30   7689
# 5          9.41         68  5500   37      41   5572
# 6          9.50        207  5900   17      25  32528
# 7          9.40        112  6600   26      29   9298
# 8          9.30        110  5250   21      28  12170
# 9          9.40         68  5500   31      38   6229
# 10         9.50        114  5400   23      28  13415
# 11         9.30        116  4800   24      30  11199
# 12         8.00        115  5500   18      22  17450
# 13         9.00         85  5250   27      34   8195
# 14         8.40         97  5000   19      24  16630
# 15         7.00        145  5000   19      24  14489
# 16         9.20        156  5200   20      24  15690
# 17         8.60         84  4800   26      32   8495
# 18         8.40         97  5000   19      24  11900
# 19         8.30        140  5500   17      20  23875
#
# [20 rows x 24 columns]

# %%
#drop na row
#how any borrara el row con solo 1 nan, al contrario si se usa all se borrara el row solo si TODOS los columnas son nan
df_dropna = dfAutosTest.dropna()
df_dropna.head(20)
# Out:
#       symboling normalized   make  fuel   aspiration doorsstyle wheels  \
# 0   alfa-romero        gas    std   two  convertible        rwd  front
# 2    volkswagen        gas    std  four        sedan        fwd  front
# 3        peugot        gas    std  four        wagon        rwd  front
# 4    mitsubishi        gas  turbo   two    hatchback        fwd  front
# 5         dodge        gas    std   two    hatchback        fwd  front
# 6       porsche        gas    std   two      hardtop        rwd   rear
# 7        toyota        gas    std   two        sedan        rwd  front
# 8          saab        gas    std  four        sedan        fwd  front
# 9         dodge        gas    std  four    hatchback        fwd  front
# 10        volvo        gas    std  four        wagon        rwd  front
# 11       toyota        gas    std   two      hardtop        rwd  front
# 12         audi        gas    std  four        sedan        4wd  front
# 13   volkswagen        gas    std  four        sedan        fwd  front
# 14       peugot        gas    std  four        sedan        rwd  front
# 15   mitsubishi        gas  turbo   two    hatchback        fwd  front
# 16       toyota        gas    std  four        sedan        rwd  front
# 17        mazda        gas    std  four        sedan        fwd  front
# 18       peugot        gas    std  four        sedan        rwd  front
# 19         audi        gas  turbo  four        sedan        fwd  front
# 20        mazda        gas    std  four    hatchback        fwd  front
#
#     enginebase  length  width  ...  engineSize  system  bore stroke  \
# 0         88.6   168.8   64.1  ...         130    mpfi  3.47   2.68
# 2         97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 3        114.2   198.9   68.4  ...         120    mpfi  3.46   2.19
# 4         93.0   157.3   63.8  ...          98    spdi  3.03   3.39
# 5         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 6         89.5   168.9   65.0  ...         194    mpfi  3.74   2.90
# 7         94.5   168.7   64.0  ...          98    mpfi  3.24   3.08
# 8         99.1   186.6   66.5  ...         121    mpfi  3.54   3.07
# 9         93.7   157.3   63.8  ...          90    2bbl  2.97   3.23
# 10       104.3   188.8   67.2  ...         141    mpfi  3.78   3.15
# 11        98.4   176.2   65.6  ...         146    mpfi  3.62   3.50
# 12        99.4   176.6   66.4  ...         136    mpfi  3.19   3.40
# 13        97.3   171.7   65.5  ...         109    mpfi  3.19   3.40
# 14       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 15        95.9   173.2   66.3  ...         156    spdi  3.59   3.86
# 16       104.5   187.8   66.5  ...         171    mpfi  3.27   3.35
# 17        98.8   177.8   66.5  ...         122    2bbl  3.39   3.39
# 18       107.9   186.7   68.4  ...         120    mpfi  3.46   3.19
# 19       105.8   192.7   71.4  ...         131    mpfi  3.13   3.40
# 20        98.8   177.8   66.5  ...         122    2bbl  3.39   3.39
#
#     compression horsepower  peak city  higway  price
# 0          9.00        111  5000   21      27  13495
# 2          9.00         85  5250   27      34   8495
# 3          8.40         95  5000   19      24  16695
# 4          7.60        102  5500   24      30   7689
# 5          9.41         68  5500   37      41   5572
# 6          9.50        207  5900   17      25  32528
# 7          9.40        112  6600   26      29   9298
# 8          9.30        110  5250   21      28  12170
# 9          9.40         68  5500   31      38   6229
# 10         9.50        114  5400   23      28  13415
# 11         9.30        116  4800   24      30  11199
# 12         8.00        115  5500   18      22  17450
# 13         9.00         85  5250   27      34   8195
# 14         8.40         97  5000   19      24  16630
# 15         7.00        145  5000   19      24  14489
# 16         9.20        156  5200   20      24  15690
# 17         8.60         84  4800   26      32   8495
# 18         8.40         97  5000   19      24  11900
# 19         8.30        140  5500   17      20  23875
# 20         8.60         84  4800   26      32  11245
#
# [20 rows x 24 columns]

# %%
#Cambiar na desde lectura
missing_cols = ["?"]
dfAutosTest1 = pd.read_csv("DataSet_Autos01.csv", names=cols, na_values= missing_cols)

# %%
dfAutosTest1.reset_index(drop=True, inplace=True)
dfAutosTest1.dropna(how="all", axis=0)
dfAutosTest1.head(20)
# Out:
#       symboling Normalized   make  fuel   aspiration doorsstyle wheels  \
# 0   alfa-romero        gas    std   two  convertible        rwd  front
# 1         dodge        gas  turbo   NaN        sedan        fwd  front
# 2    volkswagen        gas    std  four        sedan        fwd  front
# 3        peugot        gas    std  four        wagon        rwd  front
# 4    mitsubishi        gas  turbo   two    hatchback        fwd  front
# 5         dodge        gas    std   two    hatchback        fwd  front
# 6       porsche        gas    std   two      hardtop        rwd   rear
# 7        toyota        gas    std   two        sedan        rwd  front
# 8          saab        gas    std  four        sedan        fwd  front
# 9         dodge        gas    std  four    hatchback        fwd  front
# 10        volvo        gas    std  four        wagon        rwd  front
# 11       toyota        gas    std   two      hardtop        rwd  front
# 12         audi        gas    std  four        sedan        4wd  front
# 13   volkswagen        gas    std  four        sedan        fwd  front
# 14       peugot        gas    std  four        sedan        rwd  front
# 15   mitsubishi        gas  turbo   two    hatchback        fwd  front
# 16       toyota        gas    std  four        sedan        rwd  front
# 17        mazda        gas    std  four        sedan        fwd  front
# 18       peugot        gas    std  four        sedan        rwd  front
# 19         audi        gas  turbo  four        sedan        fwd  front
#
#     enginebase  length  width  ...  engine size  system  bor3 stroke  \
# 0         88.6   168.8   64.1  ...          130    mpfi  3.47   2.68
# 1         93.7   157.3   63.8  ...           98    mpfi  3.03   3.39
# 2         97.3   171.7   65.5  ...          109    mpfi  3.19   3.40
# 3        114.2   198.9   68.4  ...          120    mpfi  3.46   2.19
# 4         93.0   157.3   63.8  ...           98    spdi  3.03   3.39
# 5         93.7   157.3   63.8  ...           90    2bbl  2.97   3.23
# 6         89.5   168.9   65.0  ...          194    mpfi  3.74   2.90
# 7         94.5   168.7   64.0  ...           98    mpfi  3.24   3.08
# 8         99.1   186.6   66.5  ...          121    mpfi  3.54   3.07
# 9         93.7   157.3   63.8  ...           90    2bbl  2.97   3.23
# 10       104.3   188.8   67.2  ...          141    mpfi  3.78   3.15
# 11        98.4   176.2   65.6  ...          146    mpfi  3.62   3.50
# 12        99.4   176.6   66.4  ...          136    mpfi  3.19   3.40
# 13        97.3   171.7   65.5  ...          109    mpfi  3.19   3.40
# 14       107.9   186.7   68.4  ...          120    mpfi  3.46   3.19
# 15        95.9   173.2   66.3  ...          156    spdi  3.59   3.86
# 16       104.5   187.8   66.5  ...          171    mpfi  3.27   3.35
# 17        98.8   177.8   66.5  ...          122    2bbl  3.39   3.39
# 18       107.9   186.7   68.4  ...          120    mpfi  3.46   3.19
# 19       105.8   192.7   71.4  ...          131    mpfi  3.13   3.40
#
#     compression hOrsepower    peak  CITY  Higway    price
# 0          9.00      111.0  5000.0    21      27  13495.0
# 1          7.60      102.0  5500.0    24      30   8558.0
# 2          9.00       85.0  5250.0    27      34   8495.0
# 3          8.40       95.0  5000.0    19      24  16695.0
# 4          7.60      102.0  5500.0    24      30   7689.0
# 5          9.41       68.0  5500.0    37      41   5572.0
# 6          9.50      207.0  5900.0    17      25  32528.0
# 7          9.40      112.0  6600.0    26      29   9298.0
# 8          9.30      110.0  5250.0    21      28  12170.0
# 9          9.40       68.0  5500.0    31      38   6229.0
# 10         9.50      114.0  5400.0    23      28  13415.0
# 11         9.30      116.0  4800.0    24      30  11199.0
# 12         8.00      115.0  5500.0    18      22  17450.0
# 13         9.00       85.0  5250.0    27      34   8195.0
# 14         8.40       97.0  5000.0    19      24  16630.0
# 15         7.00      145.0  5000.0    19      24  14489.0
# 16         9.20      156.0  5200.0    20      24  15690.0
# 17         8.60       84.0  4800.0    26      32   8495.0
# 18         8.40       97.0  5000.0    19      24  11900.0
# 19         8.30      140.0  5500.0    17      20  23875.0
#
# [20 rows x 24 columns]

# %%
dfAutosTest2 = dfAutosTest1.dropna(how="any", axis=0)
dfAutosTest2.head(20)
# Out:
#       symboling Normalized   make  fuel   aspiration doorsstyle wheels  \
# 0   alfa-romero        gas    std   two  convertible        rwd  front
# 2    volkswagen        gas    std  four        sedan        fwd  front
# 3        peugot        gas    std  four        wagon        rwd  front
# 4    mitsubishi        gas  turbo   two    hatchback        fwd  front
# 5         dodge        gas    std   two    hatchback        fwd  front
# 6       porsche        gas    std   two      hardtop        rwd   rear
# 7        toyota        gas    std   two        sedan        rwd  front
# 8          saab        gas    std  four        sedan        fwd  front
# 9         dodge        gas    std  four    hatchback        fwd  front
# 10        volvo        gas    std  four        wagon        rwd  front
# 11       toyota        gas    std   two      hardtop        rwd  front
# 12         audi        gas    std  four        sedan        4wd  front
# 13   volkswagen        gas    std  four        sedan        fwd  front
# 14       peugot        gas    std  four        sedan        rwd  front
# 15   mitsubishi        gas  turbo   two    hatchback        fwd  front
# 16       toyota        gas    std  four        sedan        rwd  front
# 17        mazda        gas    std  four        sedan        fwd  front
# 18       peugot        gas    std  four        sedan        rwd  front
# 19         audi        gas  turbo  four        sedan        fwd  front
# 20        mazda        gas    std  four    hatchback        fwd  front
#
#     enginebase  length  width  ...  engine size  system  bor3 stroke  \
# 0         88.6   168.8   64.1  ...          130    mpfi  3.47   2.68
# 2         97.3   171.7   65.5  ...          109    mpfi  3.19   3.40
# 3        114.2   198.9   68.4  ...          120    mpfi  3.46   2.19
# 4         93.0   157.3   63.8  ...           98    spdi  3.03   3.39
# 5         93.7   157.3   63.8  ...           90    2bbl  2.97   3.23
# 6         89.5   168.9   65.0  ...          194    mpfi  3.74   2.90
# 7         94.5   168.7   64.0  ...           98    mpfi  3.24   3.08
# 8         99.1   186.6   66.5  ...          121    mpfi  3.54   3.07
# 9         93.7   157.3   63.8  ...           90    2bbl  2.97   3.23
# 10       104.3   188.8   67.2  ...          141    mpfi  3.78   3.15
# 11        98.4   176.2   65.6  ...          146    mpfi  3.62   3.50
# 12        99.4   176.6   66.4  ...          136    mpfi  3.19   3.40
# 13        97.3   171.7   65.5  ...          109    mpfi  3.19   3.40
# 14       107.9   186.7   68.4  ...          120    mpfi  3.46   3.19
# 15        95.9   173.2   66.3  ...          156    spdi  3.59   3.86
# 16       104.5   187.8   66.5  ...          171    mpfi  3.27   3.35
# 17        98.8   177.8   66.5  ...          122    2bbl  3.39   3.39
# 18       107.9   186.7   68.4  ...          120    mpfi  3.46   3.19
# 19       105.8   192.7   71.4  ...          131    mpfi  3.13   3.40
# 20        98.8   177.8   66.5  ...          122    2bbl  3.39   3.39
#
#     compression hOrsepower    peak  CITY  Higway    price
# 0          9.00      111.0  5000.0    21      27  13495.0
# 2          9.00       85.0  5250.0    27      34   8495.0
# 3          8.40       95.0  5000.0    19      24  16695.0
# 4          7.60      102.0  5500.0    24      30   7689.0
# 5          9.41       68.0  5500.0    37      41   5572.0
# 6          9.50      207.0  5900.0    17      25  32528.0
# 7          9.40      112.0  6600.0    26      29   9298.0
# 8          9.30      110.0  5250.0    21      28  12170.0
# 9          9.40       68.0  5500.0    31      38   6229.0
# 10         9.50      114.0  5400.0    23      28  13415.0
# 11         9.30      116.0  4800.0    24      30  11199.0
# 12         8.00      115.0  5500.0    18      22  17450.0
# 13         9.00       85.0  5250.0    27      34   8195.0
# 14         8.40       97.0  5000.0    19      24  16630.0
# 15         7.00      145.0  5000.0    19      24  14489.0
# 16         9.20      156.0  5200.0    20      24  15690.0
# 17         8.60       84.0  4800.0    26      32   8495.0
# 18         8.40       97.0  5000.0    19      24  11900.0
# 19         8.30      140.0  5500.0    17      20  23875.0
# 20         8.60       84.0  4800.0    26      32  11245.0
#
# [20 rows x 24 columns]

# %%
dfAutosTest3 = dfAutosTest1.dropna(how="any", axis=1)
dfAutosTest3.head(20)
# Out:
#       symboling Normalized   make   aspiration doorsstyle wheels  enginebase  \
# 0   alfa-romero        gas    std  convertible        rwd  front        88.6
# 1         dodge        gas  turbo        sedan        fwd  front        93.7
# 2    volkswagen        gas    std        sedan        fwd  front        97.3
# 3        peugot        gas    std        wagon        rwd  front       114.2
# 4    mitsubishi        gas  turbo    hatchback        fwd  front        93.0
# 5         dodge        gas    std    hatchback        fwd  front        93.7
# 6       porsche        gas    std      hardtop        rwd   rear        89.5
# 7        toyota        gas    std        sedan        rwd  front        94.5
# 8          saab        gas    std        sedan        fwd  front        99.1
# 9         dodge        gas    std    hatchback        fwd  front        93.7
# 10        volvo        gas    std        wagon        rwd  front       104.3
# 11       toyota        gas    std      hardtop        rwd  front        98.4
# 12         audi        gas    std        sedan        4wd  front        99.4
# 13   volkswagen        gas    std        sedan        fwd  front        97.3
# 14       peugot        gas    std        sedan        rwd  front       107.9
# 15   mitsubishi        gas  turbo    hatchback        fwd  front        95.9
# 16       toyota        gas    std        sedan        rwd  front       104.5
# 17        mazda        gas    std        sedan        fwd  front        98.8
# 18       peugot        gas    std        sedan        rwd  front       107.9
# 19         audi        gas  turbo        sedan        fwd  front       105.8
#
#     length  width  heingt  curb engineType Cylind3rs  engine size system  \
# 0    168.8   64.1    48.8  2548       dohc      four          130   mpfi
# 1    157.3   63.8    50.6  2191        ohc      four           98   mpfi
# 2    171.7   65.5    55.7  2275        ohc      four          109   mpfi
# 3    198.9   68.4    56.7  3285          l      four          120   mpfi
# 4    157.3   63.8    50.8  2145        ohc      four           98   spdi
# 5    157.3   63.8    50.8  1876        ohc      four           90   2bbl
# 6    168.9   65.0    51.6  2756       ohcf       six          194   mpfi
# 7    168.7   64.0    52.6  2265       dohc      four           98   mpfi
# 8    186.6   66.5    56.1  2695        ohc      four          121   mpfi
# 9    157.3   63.8    50.6  1967        ohc      four           90   2bbl
# 10   188.8   67.2    57.5  3034        ohc      four          141   mpfi
# 11   176.2   65.6    52.0  2679        ohc      four          146   mpfi
# 12   176.6   66.4    54.3  2824        ohc      five          136   mpfi
# 13   171.7   65.5    55.7  2212        ohc      four          109   mpfi
# 14   186.7   68.4    56.7  3075          l      four          120   mpfi
# 15   173.2   66.3    50.2  2926        ohc      four          156   spdi
# 16   187.8   66.5    54.1  3131       dohc       six          171   mpfi
# 17   177.8   66.5    55.5  2410        ohc      four          122   2bbl
# 18   186.7   68.4    56.7  3020          l      four          120   mpfi
# 19   192.7   71.4    55.9  3086        ohc      five          131   mpfi
#
#     compression  CITY  Higway
# 0          9.00    21      27
# 1          7.60    24      30
# 2          9.00    27      34
# 3          8.40    19      24
# 4          7.60    24      30
# 5          9.41    37      41
# 6          9.50    17      25
# 7          9.40    26      29
# 8          9.30    21      28
# 9          9.40    31      38
# 10         9.50    23      28
# 11         9.30    24      30
# 12         8.00    18      22
# 13         9.00    27      34
# 14         8.40    19      24
# 15         7.00    19      24
# 16         9.20    20      24
# 17         8.60    26      32
# 18         8.40    19      24
# 19         8.30    17      20

# %% [markdown]
# <h4>Fillna metodo</h4>
# <h5>ffill => Usar el valor row previo para llenar el na actual</h5>
# <h5>bfill => Usar el valor row despues para llenar el na actual</h5>

# %%
dfAutosTest4 = dfAutosTest1.fillna(method="ffill")
dfAutosTest4.head(5)
# Out:
#      symboling Normalized   make  fuel   aspiration doorsstyle wheels  \
# 0  alfa-romero        gas    std   two  convertible        rwd  front
# 1        dodge        gas  turbo   two        sedan        fwd  front
# 2   volkswagen        gas    std  four        sedan        fwd  front
# 3       peugot        gas    std  four        wagon        rwd  front
# 4   mitsubishi        gas  turbo   two    hatchback        fwd  front
#
#    enginebase  length  width  ...  engine size  system  bor3 stroke  \
# 0        88.6   168.8   64.1  ...          130    mpfi  3.47   2.68
# 1        93.7   157.3   63.8  ...           98    mpfi  3.03   3.39
# 2        97.3   171.7   65.5  ...          109    mpfi  3.19   3.40
# 3       114.2   198.9   68.4  ...          120    mpfi  3.46   2.19
# 4        93.0   157.3   63.8  ...           98    spdi  3.03   3.39
#
#    compression hOrsepower    peak  CITY  Higway    price
# 0          9.0      111.0  5000.0    21      27  13495.0
# 1          7.6      102.0  5500.0    24      30   8558.0
# 2          9.0       85.0  5250.0    27      34   8495.0
# 3          8.4       95.0  5000.0    19      24  16695.0
# 4          7.6      102.0  5500.0    24      30   7689.0
#
# [5 rows x 24 columns]

# %%
dfAutosTest5 = dfAutosTest1.fillna(method="bfill")
dfAutosTest5.head(5)
# Out:
#      symboling Normalized   make  fuel   aspiration doorsstyle wheels  \
# 0  alfa-romero        gas    std   two  convertible        rwd  front
# 1        dodge        gas  turbo  four        sedan        fwd  front
# 2   volkswagen        gas    std  four        sedan        fwd  front
# 3       peugot        gas    std  four        wagon        rwd  front
# 4   mitsubishi        gas  turbo   two    hatchback        fwd  front
#
#    enginebase  length  width  ...  engine size  system  bor3 stroke  \
# 0        88.6   168.8   64.1  ...          130    mpfi  3.47   2.68
# 1        93.7   157.3   63.8  ...           98    mpfi  3.03   3.39
# 2        97.3   171.7   65.5  ...          109    mpfi  3.19   3.40
# 3       114.2   198.9   68.4  ...          120    mpfi  3.46   2.19
# 4        93.0   157.3   63.8  ...           98    spdi  3.03   3.39
#
#    compression hOrsepower    peak  CITY  Higway    price
# 0          9.0      111.0  5000.0    21      27  13495.0
# 1          7.6      102.0  5500.0    24      30   8558.0
# 2          9.0       85.0  5250.0    27      34   8495.0
# 3          8.4       95.0  5000.0    19      24  16695.0
# 4          7.6      102.0  5500.0    24      30   7689.0
#
# [5 rows x 24 columns]

# %%
dfTest = pd.DataFrame({'A': [1, None, 4,  None, 5]})

# %%
dfTest.fillna(method="ffill" , inplace=True)
dfTest.head(5)

# %%
# dfTest.interpolate(method='polynomial', order=2)
# dfTest.head(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'scipy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 dfTest.interpolate(method='polynomial', order=2)
#       2 dfTest.head(5)
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\generic.py:8518, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8516 else:
#    8517     index = missing.get_interp_index(method, obj.index)
# -> 8518     new_data = obj._mgr.interpolate(
#    8519         method=method,
#    8520         index=index,
#    8521         limit=limit,
#    8522         limit_direction=limit_direction,
#    8523         limit_area=limit_area,
#    8524         inplace=inplace,
#    8525         downcast=downcast,
#    8526         **kwargs,
#    8527     )
#    8529 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8530 if should_transpose:
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\internals\base.py:291, in DataManager.interpolate(self, inplace, **kwargs)
#     290 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 291     return self.apply_with_block(
#     292         "interpolate",
#     293         inplace=inplace,
#     294         **kwargs,
#     295         using_cow=using_copy_on_write(),
#     296         already_warned=_AlreadyWarned(),
#     297     )
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\internals\blocks.py:1863, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, downcast, using_cow, already_warned, **kwargs)
#    1860 copy, refs = self._get_refs_and_copy(using_cow, inplace)
#    1862 # Dispatch to the EA method.
# -> 1863 new_values = self.array_values.interpolate(
#    1864     method=method,
#    1865     axis=self.ndim - 1,
#    1866     index=index,
#    1867     limit=limit,
#    1868     limit_direction=limit_direction,
#    1869     limit_area=limit_area,
#    1870     copy=copy,
#    1871     **kwargs,
#    1872 )
#    1873 data = extract_array(new_values, extract_numpy=True)
#    1875 if (
#    1876     not copy
#    1877     and warn_copy_on_write()
#    1878     and already_warned is not None
#    1879     and not already_warned.warned_already
#    1880 ):
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\arrays\numpy_.py:302, in NumpyExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#     299     out_data = self._ndarray.copy()
#     301 # TODO: assert we have floating dtype?
# --> 302 missing.interpolate_2d_inplace(
#     303     out_data,
#     304     method=method,
#     305     axis=axis,
#     306     index=index,
#     307     limit=limit,
#     308     limit_direction=limit_direction,
#     309     limit_area=limit_area,
#     310     **kwargs,
#     311 )
#     312 if not copy:
#     313     return self
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\missing.py:410, in interpolate_2d_inplace(data, index, axis, method, limit, limit_direction, limit_area, fill_value, mask, **kwargs)
#     391     _interpolate_1d(
#     392         indices=indices,
#     393         yvalues=yvalues,
#    (...)    401         **kwargs,
#     402     )
#     404 # error: Argument 1 to "apply_along_axis" has incompatible type
#     405 # "Callable[[ndarray[Any, Any]], None]"; expected "Callable[...,
#     406 # Union[_SupportsArray[dtype[<nothing>]], Sequence[_SupportsArray
#     407 # [dtype[<nothing>]]], Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]],
#     408 # Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]],
#     409 # Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"
# --> 410 np.apply_along_axis(func, axis, data)
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\numpy\lib\_shape_base_impl.py:393, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     389 except StopIteration:
#     390     raise ValueError(
#     391         'Cannot apply_along_axis when any iteration dimensions are 0'
#     392     ) from None
# --> 393 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     395 # build a buffer for storing evaluations of func1d.
#     396 # remove the requested axis, and add the new ones on the end.
#     397 # laid out so that each write is contiguous.
#     398 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
#     399 if not isinstance(res, matrix):
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\missing.py:391, in interpolate_2d_inplace.<locals>.func(yvalues)
#     388 def func(yvalues: np.ndarray) -> None:
#     389     # process 1-d slices in the axis direction
# --> 391     _interpolate_1d(
#     392         indices=indices,
#     393         yvalues=yvalues,
#     394         method=method,
#     395         limit=limit,
#     396         limit_direction=limit_direction,
#     397         limit_area=limit_area_validated,
#     398         fill_value=fill_value,
#     399         bounds_error=False,
#     400         mask=mask,
#     401         **kwargs,
#     402     )
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\missing.py:528, in _interpolate_1d(indices, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, mask, **kwargs)
#     524     yvalues[invalid] = np.interp(
#     525         indices[invalid], indices[valid][indexer], yvalues[valid][indexer]
#     526     )
#     527 else:
# --> 528     yvalues[invalid] = _interpolate_scipy_wrapper(
#     529         indices[valid],
#     530         yvalues[valid],
#     531         indices[invalid],
#     532         method=method,
#     533         fill_value=fill_value,
#     534         bounds_error=bounds_error,
#     535         order=order,
#     536         **kwargs,
#     537     )
#     539 if mask is not None:
#     540     mask[:] = False
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\core\missing.py:565, in _interpolate_scipy_wrapper(x, y, new_x, method, fill_value, bounds_error, order, **kwargs)
#     559 """
#     560 Passed off to scipy.interpolate.interp1d. method is scipy's kind.
#     561 Returns an array interpolated at new_x.  Add any new methods to
#     562 the list in _clean_interp_method.
#     563 """
#     564 extra = f"{method} interpolation requires SciPy."
# --> 565 import_optional_dependency("scipy", extra=extra)
#     566 from scipy import interpolate
#     568 new_x = np.asarray(new_x)
#
# File ~\AppData\Local\anaconda3\envs\data_a\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'scipy'. polynomial interpolation requires SciPy. Use pip or conda to install scipy.
